# %%
'''Variable '''

height = 1.79
weight = 68.7
bmi = weight / height ** 2

print(bmi)
# Out:
# 21.44127836209856

# %%
'''Python type'''
# to check out the type use the type function

type(bmi)
# Out:
# float

# %%
x = 6

type(x)
# Out:
# int

# %%
y = 'book'

type(y)
# Out:
# str

# %%
x = True
y = False

type(x)
# Out:
# bool

# %%
'''LIST'''
#A list is a simple way to give a sing name to a collection of values
# List can contain any type, contain different types
# List can contain list.
# Out:
# 'LIST'

# %%
fam = ['Ada', 'Jane', 'Joy', 'Grace']

print(fam)
# Out:
# ['Ada', 'Jane', 'Joy', 'Grace']
